# %%
import geopandas as gpd

gdf = gpd.read_file("attachments\DM_20231020_125544.json")

gdf = gdf.to_crs(epsg=4326)

gdf["geometry"] = gdf["geometry"].centroid


print(gdf)
# Out:
#           FILE_REF                                           NAME     NAME_TC  \
# 0        AM77-0015                        Rock Carvings on Po Toi        蒲台石刻
# 1    AM78-0238(01)  Site of Chinese Customs Station, Fat Tau Chau     佛頭洲稅關遺址
# 2        AM77-0017                   Rock Carvings on Cheung Chau        長洲石刻
# 3        AM77-0016                   Rock Carving at Big Wave Bay       大浪灣石刻
# 4        AM77-0091                          Lei Cheng Uk Han Tomb       李鄭屋漢墓
# ..             ...                                            ...         ...
# 165  AM77-0094(11)       Block 25 of the old Lei Yue Mun Barracks  舊鯉魚門軍營第25座
# 166    AM19-0004/B           Masonry Bridge, Pok Fu Lam Reservoir     薄扶林水塘石橋
# 167    AM20-0003/B          Bonham Road Government Primary School     般咸道官立小學
# 168      AM79-0258                      Chinese YMCA of Hong Kong  香港中華基督教青年會
# 169      AM77-0137                 Tin Hau Temple, Joss House Bay     佛堂門天后古廟
#
# ...
